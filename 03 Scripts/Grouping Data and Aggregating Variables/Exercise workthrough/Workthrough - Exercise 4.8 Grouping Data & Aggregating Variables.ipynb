# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing the ords_prods_merge dataframe
path = r'C:\Users\ztrim\06-2025 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\ztrim\\06-2025 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
# Check dataframe
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
# Create a subset
df = ords_prods_merge[:1000000]

# %%
# Check the dataframe
df.shape
# Out:
# (1000000, 21)

# %%
# Check first few rows 
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  \
# 0             0             0   2539329        1
# 1             0             0   2539329        1
# 2             0             0   2539329        1
# 3             0             0   2539329        1
# 4             0             0   2539329        1
# 5             1             1   2398795        1
# 6             1             1   2398795        1
# 7             1             1   2398795        1
# 8             1             1   2398795        1
# 9             1             1   2398795        1
#
#    customers_current_order_number  orders_day_of_week  order_hour_of_day  \
# 0                               1                   2                  8
# 1                               1                   2                  8
# 2                               1                   2                  8
# 3                               1                   2                  8
# ...

# %%
# Group a dataframe by a column
df.groupby('product_name')

# %%
# 2nd and 3rd step: Split the data into groups based on depratment_id and Apply the agg() function to each group to obtain the mean values for the “order_number” column
df.groupby('department_id').agg({'customers_current_order_number': ['mean']})
# Out:
#               customers_current_order_number
#                                         mean
# department_id
# 1                                  14.800024
# 2                                  17.091743
# 3                                  17.913544
# 4                                  17.893092
# 5                                  15.214270
# 6                                  15.382135
# 7                                  17.694027
# 8                                  16.458105
# 9                                  15.957363
# 10                                 20.091818
# 11                                 16.482026
# 12                                 15.615061
# 13                                 16.484023
# 14                                 17.524632
# 15                                 15.691875
# 16                                 18.014071
# 17                                 16.150593
# 18                                 19.602850
# ...

# %%
# Using 'mean' instead will produce the same results but look slightly different
df.groupby('department_id')['customers_current_order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: customers_current_order_number, dtype: float64

# %%
# Produce the mean, min and max 
df.groupby('department_id').agg({'customers_current_order_number': ['mean', 'min', 'max']})
# Out:
#               customers_current_order_number
#                                         mean min max
# department_id
# 1                                  14.800024   1  99
# 2                                  17.091743   1  98
# 3                                  17.913544   1  99
# 4                                  17.893092   1  99
# 5                                  15.214270   1  99
# 6                                  15.382135   1  99
# 7                                  17.694027   1  99
# 8                                  16.458105   1  91
# 9                                  15.957363   1  99
# 10                                 20.091818   1  99
# 11                                 16.482026   1  99
# 12                                 15.615061   1  99
# 13                                 16.484023   1  99
# 14                                 17.524632   1  99
# 15                                 15.691875   1  99
# 16                                 18.014071   1  99
# ...

# %%
# Split the data into groups based on user_id column, Apply transform() to customers_current_order_number, create a new column max_order
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['customers_current_order_number'].transform(np.max)
# Out:
# C:\Users\ztrim\AppData\Local\Temp\ipykernel_16456\2469252225.py:2: FutureWarning: The provided callable <function max at 0x00000293E388C4A0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['customers_current_order_number'].transform(np.max)

# %%
# Check the columns
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  \
# 0              0             0   2539329        1
# 1              0             0   2539329        1
# 2              0             0   2539329        1
# 3              0             0   2539329        1
# 4              0             0   2539329        1
# 5              1             1   2398795        1
# 6              1             1   2398795        1
# 7              1             1   2398795        1
# 8              1             1   2398795        1
# 9              1             1   2398795        1
# 10             1             1   2398795        1
# 11             2             2    473747        1
# 12             2             2    473747        1
# 13             2             2    473747        1
# 14             2             2    473747        1
#
#     customers_current_order_number  orders_day_of_week  order_hour_of_day  \
# 0                                1                   2                  8
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  \
# 0              0             0   2539329        1
# 1              0             0   2539329        1
# 2              0             0   2539329        1
# 3              0             0   2539329        1
# 4              0             0   2539329        1
# 5              1             1   2398795        1
# 6              1             1   2398795        1
# 7              1             1   2398795        1
# 8              1             1   2398795        1
# 9              1             1   2398795        1
# 10             1             1   2398795        1
# 11             2             2    473747        1
# 12             2             2    473747        1
# 13             2             2    473747        1
# 14             2             2    473747        1
# 15             2             2    473747        1
# 16             3             3   2254736        1
# 17             3             3   2254736        1
# ...

# %%
# Remove the empty row 
pd.options.display.max_rows = None

# %%
# I performed the ords_prods_merge.head(100) but deleted the output due to size

# %%
#  Creating a flag that assigns a “loyalty” label to a user ID based on its corresponding max order value
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Check if everything worked
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  \
# 0             0             0   2539329        1
# 1             0             0   2539329        1
# 2             0             0   2539329        1
# 3             0             0   2539329        1
# 4             0             0   2539329        1
#
#    customers_current_order_number  orders_day_of_week  order_hour_of_day  \
# 0                               1                   2                  8
# 1                               1                   2                  8
# 2                               1                   2                  8
# 3                               1                   2                  8
# 4                               1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  ...  \
# 0                     NaN         196                  1  ...
# 1                     NaN       14084                  2  ...
# ...

# %%
# Checking only the columns I need
ords_prods_merge[['user_id', 'loyalty_flag', 'customers_current_order_number']].head(60)
# Out:
#     user_id      loyalty_flag  customers_current_order_number
# 0         1      New customer                               1
# 1         1      New customer                               1
# 2         1      New customer                               1
# 3         1      New customer                               1
# 4         1      New customer                               1
# 5         1      New customer                               2
# 6         1      New customer                               2
# 7         1      New customer                               2
# 8         1      New customer                               2
# 9         1      New customer                               2
# 10        1      New customer                               2
# 11        1      New customer                               3
# 12        1      New customer                               3
# 13        1      New customer                               3
# ...

# %%
# Export dataframe as ords_prods_merge 
ords_prods_merge.to_pickle(os.path.join(path, '03 Scripts','ords_prods_merge.pkl'))
